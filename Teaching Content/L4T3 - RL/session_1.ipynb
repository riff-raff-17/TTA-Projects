# %% [markdown]
# ### MountainCar-v0 with Gymnasium + Stable-Baselines3 (Step-by-Step)
#
# In this notebook you'll:
#
# - Inspect the MountainCar-v0 environment (state, actions, rewards)
#
# - Run a random policy to build intuition
#
# - Train a DQN agent with Stable-Baselines3
#
# - Evaluate, record a short video, and plot learning curves

# %%
import gymnasium as gym
import numpy as np
import os, sys, time, math
import matplotlib.pyplot as plt

import stable_baselines3 as sb3
from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.results_plotter import load_results, ts2xy

print("Gymnasium:", gym.__version__)
print("Stable-Baselines3:", sb3.__version__)
# Out:
# Gymnasium: 1.2.0
# Stable-Baselines3: 2.7.0

# %% [markdown]
# ### Meet MountainCar-v0
#
# State (observation): [position, velocity] (shape: 2)
#
# Actions: {0: push left, 1: no push, 2: push right}
#
# Goal: Drive the underpowered car up the right hill (position ≥ 0.5).
#
# Reward: −1 per step until the goal is reached (shorter episodes = better).
#
# Episode ends: goal reached or after 200 steps.

# %%
env = gym.make("MountainCar-v0")
print("Observation space:", env.observation_space)
print("Action space:", env.action_space)

obs, info = env.reset(seed=42)
print("Initial observation:", obs, " | info:", info)
print("Sample action:", env.action_space.sample())
env.close()
# Out:
# Observation space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action space: Discrete(3)
# Initial observation: [-0.4452088  0.       ]  | info: {}
# Sample action: 1

# %% [markdown]
# **Roll out one random episode**
#
# This helps you see how the state evolves and why naive actions fail.
# We'll track the car's position over time and plot it.

# %%
env = gym.make("MountainCar-v0")
positions = []
rewards = []
obs, info = env.reset(seed=123)

done = False
total_r = 0
while not done:
    action = env.action_space.sample()
    obs, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated
    positions.append(obs[0])
    rewards.append(reward)
    total_r += reward

env.close()
print("Episode length:", len(rewards), " | Total reward:", total_r)

# Plot position over steps
plt.figure()
plt.plot(positions)
plt.title("Random Policy: Car Position over Time")
plt.xlabel("Step")
plt.ylabel("Position")
plt.show()
# Out:
# Episode length: 200  | Total reward: -200.0

# %% [markdown]
# Add logging and (optionally) record a short video
#
# Monitor saves per-episode rewards/lengths.
#
# RecordVideo (from Gymnasium) saves .mp4 rollouts for visualization.

# %%
from gymnasium.wrappers import RecordVideo

log_dir = "./mountaincar_logs"
video_dir = "./mountaincar_videos"
os.makedirs(log_dir, exist_ok=True)
os.makedirs(video_dir, exist_ok=True)

# Monitored env for training stats
def make_env(seed=0):
    e = gym.make("MountainCar-v0", render_mode=None)
    e = Monitor(e, filename=os.path.join(log_dir, "monitor.csv"))
    return e

# A separate env only for video (avoid slowing down training)
def make_video_env(seed=123):
    e = gym.make("MountainCar-v0", render_mode="rgb_array")
    e = RecordVideo(e, video_folder=video_dir, episode_trigger=lambda ep: True)
    return e

print("Log dir:", log_dir)
print("Video dir:", video_dir)
# Out:
# Log dir: ./mountaincar_logs
# Video dir: ./mountaincar_videos

# %% [markdown]
# Sample video! The car will move randomly.

# %%
from gymnasium.wrappers import RecordVideo

# Create a video-enabled environment
video_test_dir = "./sample_video"
os.makedirs(video_test_dir, exist_ok=True)

env_video = gym.make("MountainCar-v0", render_mode="rgb_array")
env_video = RecordVideo(env_video, video_folder=video_test_dir, episode_trigger=lambda ep: True)

obs, info = env_video.reset(seed=42)
done = False
while not done:
    action = env_video.action_space.sample()  # random action
    obs, reward, terminated, truncated, info = env_video.step(action)
    done = terminated or truncated

env_video.close()
print("Sample video saved to:", os.path.abspath(video_test_dir))
# Out:
# /Users/rafa/Desktop/GitHub/TTA-Projects/Teaching Content/L4T3 - RL/.venv/lib/python3.13/site-packages/gymnasium/wrappers/rendering.py:296: UserWarning: WARN: Overwriting existing videos at /Users/rafa/Desktop/GitHub/TTA-Projects/Teaching Content/L4T3 - RL/sample_video folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Sample video saved to: /Users/rafa/Desktop/GitHub/TTA-Projects/Teaching Content/L4T3 - RL/sample_video

# %% [markdown]
# A tiny callback to save the best model
#
# We'll compute a simple moving mean of rewards using Monitor logs and save the best-performing checkpoint.

# %%
class SaveOnBestTrainingRewardCallback(BaseCallback):
    def __init__(self, check_freq: int, log_dir: str, verbose: int = 1):
        super().__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, "best_model")
        os.makedirs(self.save_path, exist_ok=True)
        self.best_mean_reward = -np.inf

    def _on_step(self) -> bool:
        if (self.n_calls % self.check_freq) == 0:
            try:
                # Load results and compute mean reward
                x, y = ts2xy(load_results(self.log_dir), "timesteps")
                if len(y) > 0:
                    mean_reward = np.mean(y[-100:])
                    if self.verbose:
                        print(f"Step {self.n_calls} | Last-100 mean reward: {mean_reward:.2f}")
                    if mean_reward > self.best_mean_reward:
                        self.best_mean_reward = mean_reward
                        path = os.path.join(self.save_path, "best_model")
                        self.model.save(path)
                        if self.verbose:
                            print(f"✔ Saved new best model to {path}")
            except Exception as e:
                if self.verbose:
                    print("Callback warning:", e)
        return True

# %% [markdown]
# ### Train a DQN agent
#
# A good, simple baseline for discrete-action tasks like MountainCar. We'll train for a modest number of timesteps so it runs quickly.

# %%
env_train = make_env()
model = DQN(
    policy="MlpPolicy",
    env=env_train,
    learning_rate=4e-3,
    buffer_size=10_000,
    learning_starts=1_000,
    batch_size=128,
    gamma=0.98,
    train_freq=16,
    gradient_steps = 8,
    target_update_interval=600,
    exploration_fraction=0.2,   # explore for ~20% of training
    exploration_final_eps=0.07,
    verbose=1,
    tensorboard_log=os.path.join(log_dir, "tb")
)

callback = SaveOnBestTrainingRewardCallback(check_freq=5_000, log_dir=log_dir, verbose=1)
timesteps = 300_000  # try 200_000+ for better results
model.learn(total_timesteps=timesteps, callback=callback)
model.save(os.path.join(log_dir, "final_model"))
env_train.close()
print("Training done.")
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# Logging to ./mountaincar_logs/tb/DQN_5
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 30700    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 800      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 8684     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1600     |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 1.02e-05 |
# |    n_updates        | 296      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 6059     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2400     |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 3.28e-06 |
# |    n_updates        | 696      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.95     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 5251     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3200     |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 3e-05    |
# |    n_updates        | 1096     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 4959     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4000     |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 3.49e-06 |
# |    n_updates        | 1496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.926    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 4782     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4800     |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 4.48e-07 |
# |    n_updates        | 1896     |
# ----------------------------------
# Step 5000 | Last-100 mean reward: -200.00
# ✔ Saved new best model to ./mountaincar_logs/best_model/best_model
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.913    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 4550     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5600     |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 2.43e-05 |
# |    n_updates        | 2296     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.901    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 4480     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6400     |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 1.24e-06 |
# |    n_updates        | 2696     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.888    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 4434     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7200     |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 1.21e-06 |
# |    n_updates        | 3096     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.876    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 4392     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8000     |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 2.36e-05 |
# |    n_updates        | 3496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.864    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 4349     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 8800     |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 6.77e-07 |
# |    n_updates        | 3896     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 4313     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9600     |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 6.52e-07 |
# |    n_updates        | 4296     |
# ----------------------------------
# Step 10000 | Last-100 mean reward: -200.00
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.839    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 4278     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10400    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 1.45e-05 |
# |    n_updates        | 4696     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.826    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 4250     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11200    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 6.28e-07 |
# |    n_updates        | 5096     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.814    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 4230     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12000    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 6.17e-07 |
# |    n_updates        | 5496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.802    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 4209     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 12800    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 1.06e-05 |
# |    n_updates        | 5896     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.789    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 4192     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 13600    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 4.67e-07 |
# |    n_updates        | 6296     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.777    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 4177     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 14400    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 3.77e-07 |
# |    n_updates        | 6696     |
# ----------------------------------
# Step 15000 | Last-100 mean reward: -200.00
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.764    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 4162     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 15200    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 7.3e-06  |
# |    n_updates        | 7096     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.752    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 4138     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16000    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 4.04e-07 |
# |    n_updates        | 7496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.74     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 4120     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 16800    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 3.06e-07 |
# |    n_updates        | 7896     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.727    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 4110     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 17600    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 5.53e-06 |
# |    n_updates        | 8296     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.715    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 4101     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 18400    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 2.45e-07 |
# |    n_updates        | 8696     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.702    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 4092     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19200    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 2.02e-07 |
# |    n_updates        | 9096     |
# ----------------------------------
# Step 20000 | Last-100 mean reward: -200.00
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.69     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 4079     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 20000    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 7.07e-06 |
# |    n_updates        | 9496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.678    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 4068     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 20800    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 3.73e-07 |
# |    n_updates        | 9896     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.665    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 4057     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 21600    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 2.02e-07 |
# |    n_updates        | 10296    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.653    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 4047     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 22400    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 1.32e-05 |
# |    n_updates        | 10696    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.64     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 4039     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 23200    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 1.84e-07 |
# |    n_updates        | 11096    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.628    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 4032     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 24000    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 1.45e-07 |
# |    n_updates        | 11496    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.616    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 4022     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 24800    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 9.86e-06 |
# |    n_updates        | 11896    |
# ----------------------------------
# Step 25000 | Last-100 mean reward: -200.00
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.603    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 4011     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 25600    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 1.32e-07 |
# |    n_updates        | 12296    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.591    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 4003     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 26400    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 1.38e-07 |
# |    n_updates        | 12696    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.578    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 3996     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 27200    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 9.87e-06 |
# |    n_updates        | 13096    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.566    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 3991     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 28000    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 1.04e-07 |
# |    n_updates        | 13496    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.554    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 3984     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 28800    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 9.35e-08 |
# |    n_updates        | 13896    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.541    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 3977     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 29600    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 5.42e-06 |
# |    n_updates        | 14296    |
# ----------------------------------
# Step 30000 | Last-100 mean reward: -200.00
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.529    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 3969     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 30400    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 1.87e-06 |
# |    n_updates        | 14696    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.516    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 3964     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 31200    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 9.05e-08 |
# |    n_updates        | 15096    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.504    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 3957     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 32000    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 6.07e-06 |
# |    n_updates        | 15496    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.492    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 3950     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 32800    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 1.03e-07 |
# |    n_updates        | 15896    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.479    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 3944     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 33600    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 5.57e-08 |
# |    n_updates        | 16296    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.467    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 3939     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 34400    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 5.07e-06 |
# |    n_updates        | 16696    |
# ----------------------------------
# Step 35000 | Last-100 mean reward: -200.00
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.454    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 3931     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 35200    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 4.04e-08 |
# |    n_updates        | 17096    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.442    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 3922     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 36000    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 5.52e-08 |
# |    n_updates        | 17496    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.43     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 3912     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 36800    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 6.52e-06 |
# |    n_updates        | 17896    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.417    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 3900     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 37600    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 3.87e-08 |
# |    n_updates        | 18296    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.405    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 3890     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 38400    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 4.56e-08 |
# |    n_updates        | 18696    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.392    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 3878     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 39200    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 6.47e-06 |
# |    n_updates        | 19096    |
# ----------------------------------
# Step 40000 | Last-100 mean reward: -200.00
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.38     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 3872     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 40000    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 2.55e-08 |
# |    n_updates        | 19496    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.368    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 3863     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 40800    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 3.14e-08 |
# |    n_updates        | 19896    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.355    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 3859     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 41600    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 5.21e-06 |
# |    n_updates        | 20296    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.343    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 3855     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 42400    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 5.68e-08 |
# |    n_updates        | 20696    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.33     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 3850     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 43200    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 1.02e-07 |
# |    n_updates        | 21096    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.318    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 3845     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 44000    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 6.52e-06 |
# |    n_updates        | 21496    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.306    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 3840     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 44800    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 4.5e-07  |
# |    n_updates        | 21896    |
# ----------------------------------
# Step 45000 | Last-100 mean reward: -200.00
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.293    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 3835     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 45600    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 5.77e-07 |
# |    n_updates        | 22296    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.281    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 3830     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 46400    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 8.99e-06 |
# |    n_updates        | 22696    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.268    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 3828     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 47200    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 1.76e-06 |
# |    n_updates        | 23096    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.256    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 3825     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 48000    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 8.17e-07 |
# |    n_updates        | 23496    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.244    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 3822     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 48800    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 1.42e-05 |
# |    n_updates        | 23896    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.231    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 3819     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 49600    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 2.25e-06 |
# |    n_updates        | 24296    |
# ----------------------------------
# Step 50000 | Last-100 mean reward: -200.00
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.219    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 3815     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 50400    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 6.57e-07 |
# |    n_updates        | 24696    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.206    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 3812     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 51200    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 1.33e-05 |
# |    n_updates        | 25096    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.194    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 3809     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 52000    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 4.04e-07 |
# |    n_updates        | 25496    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.182    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 3806     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 52800    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 4.19e-07 |
# |    n_updates        | 25896    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.169    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 3803     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 53600    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 3.34e-06 |
# |    n_updates        | 26296    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.157    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 3800     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 54400    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 3.34e-07 |
# |    n_updates        | 26696    |
# ----------------------------------
# Step 55000 | Last-100 mean reward: -200.00
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.144    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 3796     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 55200    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 3.4e-07  |
# |    n_updates        | 27096    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.132    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 3793     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 56000    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 1.44e-05 |
# |    n_updates        | 27496    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.12     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 3790     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 56800    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 6.65e-07 |
# |    n_updates        | 27896    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.107    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 3787     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 57600    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 2.86e-07 |
# |    n_updates        | 28296    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.0948   |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 3784     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 58400    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 1.59e-06 |
# |    n_updates        | 28696    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.0824   |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 3781     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 59200    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 3.56e-07 |
# |    n_updates        | 29096    |
# ----------------------------------
# Step 60000 | Last-100 mean reward: -200.00
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 3778     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 60000    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 2.19e-07 |
# |    n_updates        | 29496    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 3775     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 60800    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 2.8e-06  |
# |    n_updates        | 29896    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 3771     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 61600    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 1.36e-07 |
# |    n_updates        | 30296    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 3768     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 62400    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 5.81e-07 |
# |    n_updates        | 30696    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 3765     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 63200    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 9.4e-06  |
# |    n_updates        | 31096    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 3763     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 64000    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 3.44e-07 |
# |    n_updates        | 31496    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 3760     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 64800    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 2.03e-07 |
# |    n_updates        | 31896    |
# ----------------------------------
# Step 65000 | Last-100 mean reward: -200.00
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 3756     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 65600    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 4.36e-05 |
# |    n_updates        | 32296    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 3754     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 66400    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 1.17e-07 |
# |    n_updates        | 32696    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 3749     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 67200    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 1.2e-07  |
# |    n_updates        | 33096    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 3745     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 68000    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 3.49e-06 |
# |    n_updates        | 33496    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 3741     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 68800    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 8.32e-08 |
# |    n_updates        | 33896    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 3739     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 69600    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 1.22e-07 |
# |    n_updates        | 34296    |
# ----------------------------------
# Step 70000 | Last-100 mean reward: -200.00
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 3735     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 70400    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.000189 |
# |    n_updates        | 34696    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 3732     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 71200    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 1.31e-07 |
# |    n_updates        | 35096    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 3730     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 72000    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 5.92e-08 |
# |    n_updates        | 35496    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# ...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 1488     |
# |    fps              | 3502     |
# |    time_elapsed     | 79       |
# |    total_timesteps  | 279461   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.121    |
# |    n_updates        | 139232   |
# ----------------------------------
# Step 280000 | Last-100 mean reward: -176.00
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 1492     |
# |    fps              | 3502     |
# |    time_elapsed     | 79       |
# |    total_timesteps  | 280072   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.186    |
# |    n_updates        | 139536   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 174      |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 1496     |
# |    fps              | 3502     |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 280710   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.117    |
# |    n_updates        | 139856   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 173      |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 1500     |
# |    fps              | 3502     |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 281378   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0843   |
# |    n_updates        | 140192   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 170      |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 1504     |
# |    fps              | 3503     |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 281955   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.15     |
# |    n_updates        | 140480   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 168      |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 1508     |
# |    fps              | 3503     |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 282547   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0624   |
# |    n_updates        | 140776   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 167      |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 1512     |
# |    fps              | 3503     |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 283212   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.15     |
# |    n_updates        | 141104   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 166      |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 1516     |
# |    fps              | 3503     |
# |    time_elapsed     | 81       |
# |    total_timesteps  | 283900   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0605   |
# |    n_updates        | 141448   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 165      |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 1520     |
# |    fps              | 3503     |
# |    time_elapsed     | 81       |
# |    total_timesteps  | 284646   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0626   |
# |    n_updates        | 141824   |
# ----------------------------------
# Step 285000 | Last-100 mean reward: -165.32
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 164      |
# |    ep_rew_mean      | -164     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 1524     |
# |    fps              | 3504     |
# |    time_elapsed     | 81       |
# |    total_timesteps  | 285358   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0636   |
# |    n_updates        | 142176   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 166      |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 1528     |
# |    fps              | 3504     |
# |    time_elapsed     | 81       |
# |    total_timesteps  | 286155   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0638   |
# |    n_updates        | 142576   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 166      |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 1532     |
# |    fps              | 3504     |
# |    time_elapsed     | 81       |
# |    total_timesteps  | 286928   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0781   |
# |    n_updates        | 142960   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 168      |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 1536     |
# |    fps              | 3504     |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 287723   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0621   |
# |    n_updates        | 143360   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 168      |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 1540     |
# |    fps              | 3505     |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 288508   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0391   |
# |    n_updates        | 143752   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 169      |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 1544     |
# |    fps              | 3505     |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 289215   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.126    |
# |    n_updates        | 144104   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 169      |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 1548     |
# |    fps              | 3505     |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 289890   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0486   |
# |    n_updates        | 144448   |
# ----------------------------------
# Step 290000 | Last-100 mean reward: -169.37
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 170      |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 1552     |
# |    fps              | 3505     |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 290559   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.092    |
# |    n_updates        | 144776   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 170      |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 1556     |
# |    fps              | 3504     |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 291268   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0964   |
# |    n_updates        | 145136   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 171      |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 1560     |
# |    fps              | 3503     |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 291939   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0745   |
# |    n_updates        | 145472   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 171      |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 1564     |
# |    fps              | 3503     |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 292582   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0765   |
# |    n_updates        | 145792   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 171      |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 1568     |
# |    fps              | 3504     |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 293295   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0992   |
# |    n_updates        | 146144   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 170      |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 1572     |
# |    fps              | 3504     |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 293918   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0569   |
# |    n_updates        | 146456   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 171      |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 1576     |
# |    fps              | 3504     |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 294676   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.134    |
# |    n_updates        | 146840   |
# ----------------------------------
# Step 295000 | Last-100 mean reward: -170.80
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 172      |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 1580     |
# |    fps              | 3504     |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 295418   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0995   |
# |    n_updates        | 147208   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 173      |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 1584     |
# |    fps              | 3503     |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 296196   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0746   |
# |    n_updates        | 147600   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 1588     |
# |    fps              | 3504     |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 296940   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0951   |
# |    n_updates        | 147968   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 1592     |
# |    fps              | 3504     |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 297711   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.1      |
# |    n_updates        | 148352   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 1596     |
# |    fps              | 3504     |
# |    time_elapsed     | 85       |
# |    total_timesteps  | 298436   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.11     |
# |    n_updates        | 148720   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 1600     |
# |    fps              | 3504     |
# |    time_elapsed     | 85       |
# |    total_timesteps  | 299151   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0955   |
# |    n_updates        | 149072   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 1604     |
# |    fps              | 3504     |
# |    time_elapsed     | 85       |
# |    total_timesteps  | 299916   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.105    |
# |    n_updates        | 149456   |
# ----------------------------------
# Step 300000 | Last-100 mean reward: -179.61
# Training done.

# %% [markdown]
# ### Evaluate the policy
#
# We measure average return over several episodes. MountainCar returns are negative; less negative is better. Success corresponds to quickly reaching the goal (position ≥ 0.5).

# %%
eval_env = gym.make("MountainCar-v0")
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, render=False, deterministic=True)
eval_env.close()
print(f"Mean reward over 10 episodes: {mean_reward:.2f} ± {std_reward:.2f}")
# Out:
# Mean reward over 10 episodes: -184.40 ± 10.70
# /Users/rafa/Desktop/GitHub/TTA-Projects/Teaching Content/L4T3 - RL/.venv/lib/python3.13/site-packages/stable_baselines3/common/evaluation.py:70: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %% [markdown]
# ### Watch a rollout (video)
#
# We'll load the best checkpoint if available, otherwise the final model, and record one episode.

# %%
# Try to load best checkpoint
best_path = os.path.join(log_dir, "best_model", "best_model.zip")
if os.path.exists(best_path):
    print("Loading best checkpoint:", best_path)
    model = DQN.load(best_path)
else:
    print("Best checkpoint not found — using final model.")
    model = DQN.load(os.path.join(log_dir, "final_model.zip"))

vid_env = make_video_env()
obs, info = vid_env.reset(seed=2025)
done = False
ep_reward = 0
while not done:
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = vid_env.step(action)
    done = terminated or truncated
    ep_reward += reward
vid_env.close()
print("Recorded one episode. Reward:", ep_reward)
print("Check the video folder:", os.path.abspath("mountaincar_videos"))
# Out:
# Loading best checkpoint: ./mountaincar_logs/best_model/best_model.zip
# /Users/rafa/Desktop/GitHub/TTA-Projects/Teaching Content/L4T3 - RL/.venv/lib/python3.13/site-packages/gymnasium/wrappers/rendering.py:296: UserWarning: WARN: Overwriting existing videos at /Users/rafa/Desktop/GitHub/TTA-Projects/Teaching Content/L4T3 - RL/mountaincar_videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Recorded one episode. Reward: -166.0
# Check the video folder: /Users/rafa/Desktop/GitHub/TTA-Projects/Teaching Content/L4T3 - RL/mountaincar_videos

# %% [markdown]
# ### Plot the learning curve
#
# We'll parse the Monitor log and plot episode rewards over training timesteps.

# %%
import pandas as pd
from glob import glob

monitor_files = glob(os.path.join(log_dir, "*.monitor.csv")) + glob(os.path.join(log_dir, "monitor.csv"))
if not monitor_files:
    print("No monitor file found. Did training run?")
else:
    # Load Monitor CSV, skip header & comments
    df = pd.read_csv(
        monitor_files[0],
        skiprows=2,            # skip the first "r,l,t" header row
        comment="#",           # skip metadata lines
        names=["r", "l", "t"]  # r: reward, l: length, t: time
    )
    df = df.astype(float)
    df["timesteps"] = df["l"].cumsum()

    # Moving average over rewards
    window = 50
    df["r_smooth"] = df["r"].rolling(window, min_periods=1).mean()

    display(df.head())

    # Plot
    plt.figure(figsize=(10, 5))
    plt.plot(df["timesteps"], df["r"], alpha=0.3, label="Raw rewards")
    plt.plot(df["timesteps"], df["r_smooth"], label=f"Smoothed (window={window})")
    plt.title("Episode Reward vs Timesteps")
    plt.xlabel("Timesteps")
    plt.ylabel("Episode Reward")
    plt.legend()
    plt.show()
# Out:
#        r      l         t  timesteps  r_smooth
# 0 -200.0  200.0  0.018835      200.0    -200.0
# 1 -200.0  200.0  0.024612      400.0    -200.0
# 2 -200.0  200.0  0.030077      600.0    -200.0
# 3 -200.0  200.0  0.035748      800.0    -200.0
# 4 -200.0  200.0  0.041643     1000.0    -200.0
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
